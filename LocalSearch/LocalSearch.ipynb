# %%
# !pip install ortools
# Out:
# Collecting ortools
#   Downloading ortools-9.1.9490-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.5 MB)
#      |████████████████████████████████| 14.5 MB 12.1 MB/s
# Collecting protobuf>=3.18.0
#   Downloading protobuf-3.19.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 43.6 MB/s
# Collecting absl-py>=0.13
#   Downloading absl_py-1.0.0-py3-none-any.whl (126 kB)
#      |████████████████████████████████| 126 kB 70.5 MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from absl-py>=0.13->ortools) (1.15.0)
# Installing collected packages: protobuf, absl-py, ortools
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.17.3
#     Uninstalling protobuf-3.17.3:
#       Successfully uninstalled protobuf-3.17.3
#   Attempting uninstall: absl-py
#     Found existing installation: absl-py 0.12.0
#     Uninstalling absl-py-0.12.0:
#       Successfully uninstalled absl-py-0.12.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-metadata 1.4.0 requires absl-py<0.13,>=0.9, but you have absl-py 1.0.0 which is incompatible.
# Successfully installed absl-py-1.0.0 ortools-9.1.9490 protobuf-3.19.1

# %%
from ortools.linear_solver import pywraplp
from ortools.constraint_solver import routing_enums_pb2
from ortools.constraint_solver import pywrapcp
import time

"""Simple Pickup Delivery Problem (PDP)."""

def create_data_model():
    """Stores the data for the problem."""
    data = {}
    data['distance_matrix'] = distanceMatrix
    data['pickups_deliveries'] = [
      [i, i+hanhkhach+goihang] for i in range(1, hanhkhach+goihang+1)
    ]
    data['demands'] = [0 for i in range(hanhkhach+1)] + khoiLuongGoiHang + [0 for i in range(hanhkhach)] + list(map(lambda x: -x, khoiLuongGoiHang))
    data['passengers'] = [0] + [1 for i in range(hanhkhach)] + [0 for i in range(goihang)] + [-1 for i in range(hanhkhach)] + [0 for i in range(goihang)]
    data['vehicle_capacities'] = khoiLuongToiDaMoiXe
    data['passenger_capacities'] = [1 for i in range(vehicleNumber)]
    data['num_vehicles'] = vehicleNumber
    data['depot'] = 0
    return data

def print_solution(data, manager, routing, solution, f, start):
    """Prints solution on console."""
    print(f'Objective: {solution.ObjectiveValue()}')
    f.writelines(f'Objective: {solution.ObjectiveValue()}\n')
    output_distance = 0
    
    for vehicle_id in range(data['num_vehicles']):
        index = routing.Start(vehicle_id)
        route_load = 0
        pack_load = 0
        plan_output = 'Route for vehicle {}:\n'.format(vehicle_id)
        route_distance = 0
        while not routing.IsEnd(index):
            node_index = manager.IndexToNode(index)
            route_load += data['passengers'][node_index]
            pack_load += data['demands'][node_index]
            plan_output += ' {0} Load({1} and {2}) -> '.format(node_index, route_load, pack_load)
            previous_index = index
            index = solution.Value(routing.NextVar(index))
            route_distance += routing.GetArcCostForVehicle(
                previous_index, index, vehicle_id)
        plan_output += ' {0} Load({1} and {2})\n'.format(manager.IndexToNode(index),
                                                 route_load, pack_load)
        plan_output += 'Distance of the route: {}m\n'.format(route_distance)
        print(plan_output)
        f.writelines(plan_output + '\n')
        output_distance = max(output_distance, route_distance)
    print('Maximum of all routes: {}m'.format(output_distance))
    f.writelines('Maximum of all routes: {}\n'.format(output_distance))
    f.writelines('Problem solved in %f seconds\n' % (time.time() - start))


def mains(f, count):
    """Entry point of the program."""
    # Instantiate the data problem.
    start = time.time()
    data = create_data_model()

    # Create the routing index manager.
    manager = pywrapcp.RoutingIndexManager(len(data['distance_matrix']),
                                           data['num_vehicles'], data['depot'])

    # Create Routing Model.
    routing = pywrapcp.RoutingModel(manager)


    # Define cost of each arc.
    def distance_callback(from_index, to_index):
        """Returns the manhattan distance between the two nodes."""
        # Convert from routing variable Index to distance matrix NodeIndex.
        from_node = manager.IndexToNode(from_index)
        to_node = manager.IndexToNode(to_index)
        return data['distance_matrix'][from_node][to_node]

    transit_callback_index = routing.RegisterTransitCallback(distance_callback)
    routing.SetArcCostEvaluatorOfAllVehicles(transit_callback_index)

    # Add Distance constraint.
    dimension_name = 'Distance'
    routing.AddDimension(
        transit_callback_index,
        0,  # no slack
        3000,  # vehicle maximum travel distance
        True,  # start cumul to zero
        dimension_name)
    distance_dimension = routing.GetDimensionOrDie(dimension_name)
    distance_dimension.SetGlobalSpanCostCoefficient(100)
        
    # Add Capacity constraint.
    def demand_callback(from_index):
        """Returns the demand of the node."""
        # Convert from routing variable Index to demands NodeIndex.
        from_node = manager.IndexToNode(from_index)
        return data['demands'][from_node]
    demand_callback_index = routing.RegisterUnaryTransitCallback(
        demand_callback)
    routing.AddDimensionWithVehicleCapacity(
        demand_callback_index,
        0,  # null capacity slack
        data['vehicle_capacities'],  # vehicle maximum capacities
        True,  # start cumul to zero
        'Capacity')

    # Add Passenger constraint.
    def demand_passenger_callback(from_index):
        """Returns the demand of the node."""
        # Convert from routing variable Index to demands NodeIndex.
        from_node = manager.IndexToNode(from_index)
        return data['passengers'][from_node]
    demand_passenger_callback_index = routing.RegisterUnaryTransitCallback(
        demand_passenger_callback)
    routing.AddDimensionWithVehicleCapacity(
        demand_passenger_callback_index,
        0,  # null capacity slack
        data['passenger_capacities'],  # vehicle maximum capacities
        True,  # start cumul to zero
        'Passenger Capacity')
    
    # Define Transportation Requests.
    for request in data['pickups_deliveries']:
        pickup_index = manager.NodeToIndex(request[0])
        delivery_index = manager.NodeToIndex(request[1])
        routing.AddPickupAndDelivery(pickup_index, delivery_index)
        routing.solver().Add(
            routing.VehicleVar(pickup_index) == routing.VehicleVar(
                delivery_index))
        routing.solver().Add(
            distance_dimension.CumulVar(pickup_index) <=
            distance_dimension.CumulVar(delivery_index))
        
    # Setting first solution heuristic.
    search_parameters = pywrapcp.DefaultRoutingSearchParameters()
    search_parameters.first_solution_strategy = (
        routing_enums_pb2.FirstSolutionStrategy.PARALLEL_CHEAPEST_INSERTION)
    search_parameters.local_search_metaheuristic = (
    routing_enums_pb2.LocalSearchMetaheuristic.GUIDED_LOCAL_SEARCH)
    search_parameters.time_limit.FromSeconds(count ** 3)

    # Solve the problem.
    solution = routing.SolveWithParameters(search_parameters)

    # Print solution on console.
    if solution:
        print_solution(data, manager, routing, solution, f, start)
for count in range(1, 11):
    tmp = []
    with open(r"/content/drive/MyDrive/Tối ưu/data/DataSet{}/input.txt".format(count),"r") as f:
      
     for i in f.readlines():
        i = i.replace("\n","")
        i = i.rstrip(" ").split(" ")
        tmp.append([int(j) for j in i])
    f.close()

    distanceMatrix = tmp[3:]
    hanhkhach = tmp[0][0]
    goihang = tmp[0][1]
    vehicleNumber = tmp[0][2]
    khoiLuongGoiHang = tmp[1]
    khoiLuongToiDaMoiXe = tmp[2]
    f = open("/content/drive/MyDrive/Tối ưu/data/DataSet{}/output-parallel.txt".format(count),"w+")
    mains(f, count)
    f.close()
# Out:
# Objective: 19344
# Route for vehicle 0:
#  0 Load(0 and 0) ->  7 Load(0 and 17) ->  14 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 185m
#
# Route for vehicle 1:
#  0 Load(0 and 0) ->  4 Load(0 and 13) ->  6 Load(0 and 37) ->  11 Load(0 and 24) ->  1 Load(1 and 24) ->  13 Load(1 and 0) ->  8 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 171m
#
# Route for vehicle 2:
#  0 Load(0 and 0) ->  5 Load(0 and 19) ->  2 Load(1 and 19) ->  12 Load(1 and 0) ->  3 Load(1 and 10) ->  10 Load(1 and 0) ->  9 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 188m
#
# Maximum of all routes: 188m
# Objective: 20109
# Route for vehicle 0:
#  0 Load(0 and 0) ->  2 Load(1 and 0) ->  11 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 194m
#
# Route for vehicle 1:
#  0 Load(0 and 0) ->  4 Load(1 and 0) ->  13 Load(0 and 0) ->  7 Load(0 and 6) ->  5 Load(0 and 21) ->  16 Load(0 and 15) ->  14 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 136m
#
# Route for vehicle 2:
#  0 Load(0 and 0) ->  6 Load(0 and 13) ->  9 Load(0 and 32) ->  15 Load(0 and 19) ->  18 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 191m
#
# Route for vehicle 3:
#  0 Load(0 and 0) ->  1 Load(1 and 0) ->  8 Load(1 and 23) ->  10 Load(0 and 23) ->  17 Load(0 and 0) ->  3 Load(1 and 0) ->  12 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 188m
#
# Maximum of all routes: 194m
# Objective: 22790
# Route for vehicle 0:
#  0 Load(0 and 0) ->  5 Load(1 and 0) ->  15 Load(0 and 0) ->  7 Load(0 and 20) ->  17 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 218m
#
# Route for vehicle 1:
#  0 Load(0 and 0) ->  4 Load(1 and 0) ->  9 Load(1 and 23) ->  19 Load(1 and 0) ->  14 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 192m
#
# Route for vehicle 2:
#  0 Load(0 and 0) ->  3 Load(1 and 0) ->  13 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 157m
#
# Route for vehicle 3:
#  0 Load(0 and 0) ->  10 Load(0 and 23) ->  1 Load(1 and 23) ->  20 Load(1 and 0) ->  11 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 206m
#
# Route for vehicle 4:
#  0 Load(0 and 0) ->  8 Load(0 and 19) ->  2 Load(1 and 19) ->  12 Load(0 and 19) ->  6 Load(1 and 19) ->  16 Load(0 and 19) ->  18 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 217m
#
# Maximum of all routes: 218m
# Objective: 21181
# Route for vehicle 0:
#  0 Load(0 and 0) ->  12 Load(0 and 12) ->  13 Load(0 and 29) ->  5 Load(1 and 29) ->  26 Load(1 and 17) ->  19 Load(0 and 17) ->  1 Load(1 and 17) ->  27 Load(1 and 0) ->  15 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 188m
#
# Route for vehicle 1:
#  0 Load(0 and 0) ->  7 Load(1 and 0) ->  21 Load(0 and 0) ->  3 Load(1 and 0) ->  17 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 142m
#
# Route for vehicle 2:
#  0 Load(0 and 0) ->  6 Load(1 and 0) ->  14 Load(1 and 17) ->  20 Load(0 and 17) ->  28 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 189m
#
# Route for vehicle 3:
#  0 Load(0 and 0) ->  2 Load(1 and 0) ->  16 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 184m
#
# Route for vehicle 4:
#  0 Load(0 and 0) ->  11 Load(0 and 11) ->  9 Load(0 and 19) ->  23 Load(0 and 11) ->  25 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 200m
#
# Route for vehicle 5:
#  0 Load(0 and 0) ->  8 Load(1 and 0) ->  22 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 92m
#
# Route for vehicle 6:
#  0 Load(0 and 0) ->  4 Load(1 and 0) ->  10 Load(1 and 24) ->  18 Load(0 and 24) ->  24 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 186m
#
# Maximum of all routes: 200m
# Objective: 23467
# Route for vehicle 0:
#  0 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 0m
#
# Route for vehicle 1:
#  0 Load(0 and 0) ->  11 Load(0 and 18) ->  8 Load(1 and 18) ->  30 Load(0 and 18) ->  33 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 215m
#
# Route for vehicle 2:
#  0 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 0m
#
# Route for vehicle 3:
#  0 Load(0 and 0) ->  21 Load(0 and 23) ->  3 Load(1 and 23) ->  25 Load(0 and 23) ->  43 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 192m
#
# Route for vehicle 4:
#  0 Load(0 and 0) ->  4 Load(1 and 0) ->  26 Load(0 and 0) ->  10 Load(1 and 0) ->  32 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 172m
#
# Route for vehicle 5:
#  0 Load(0 and 0) ->  9 Load(1 and 0) ->  16 Load(1 and 13) ->  17 Load(1 and 26) ->  31 Load(0 and 26) ->  5 Load(1 and 26) ->  38 Load(1 and 13) ->  39 Load(1 and 0) ->  27 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 201m
#
# Route for vehicle 6:
#  0 Load(0 and 0) ->  7 Load(1 and 0) ->  19 Load(1 and 23) ->  41 Load(1 and 0) ->  29 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 186m
#
# Route for vehicle 7:
#  0 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 0m
#
# Route for vehicle 8:
#  0 Load(0 and 0) ->  13 Load(0 and 23) ->  35 Load(0 and 0) ->  15 Load(0 and 18) ->  6 Load(1 and 18) ->  18 Load(1 and 25) ->  37 Load(1 and 7) ->  28 Load(0 and 7) ->  1 Load(1 and 7) ->  40 Load(1 and 0) ->  23 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 205m
#
# Route for vehicle 9:
#  0 Load(0 and 0) ->  12 Load(0 and 15) ->  20 Load(0 and 28) ->  42 Load(0 and 15) ->  22 Load(0 and 23) ->  44 Load(0 and 15) ->  34 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 177m
#
# Route for vehicle 10:
#  0 Load(0 and 0) ->  14 Load(0 and 9) ->  2 Load(1 and 9) ->  36 Load(1 and 0) ->  24 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 219m
#
# Route for vehicle 11:
#  0 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 0m
#
# Maximum of all routes: 219m
# Objective: 23402
# Route for vehicle 0:
#  0 Load(0 and 0) ->  3 Load(1 and 0) ->  15 Load(1 and 16) ->  39 Load(1 and 0) ->  27 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 190m
#
# Route for vehicle 1:
#  0 Load(0 and 0) ->  6 Load(1 and 0) ->  22 Load(1 and 6) ->  30 Load(0 and 6) ->  10 Load(1 and 6) ->  16 Load(1 and 17) ->  46 Load(1 and 11) ->  34 Load(0 and 11) ->  40 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 212m
#
# Route for vehicle 2:
#  0 Load(0 and 0) ->  1 Load(1 and 0) ->  25 Load(0 and 0) ->  12 Load(1 and 0) ->  36 Load(0 and 0) ->  8 Load(1 and 0) ->  32 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 210m
#
# Route for vehicle 3:
#  0 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 0m
#
# Route for vehicle 4:
#  0 Load(0 and 0) ->  20 Load(0 and 7) ->  23 Load(0 and 12) ->  4 Load(1 and 12) ->  44 Load(1 and 5) ->  47 Load(1 and 0) ->  28 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 214m
#
# Route for vehicle 5:
#  0 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 0m
#
# Route for vehicle 6:
#  0 Load(0 and 0) ->  9 Load(1 and 0) ->  17 Load(1 and 17) ->  33 Load(0 and 17) ->  41 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 188m
#
# Route for vehicle 7:
#  0 Load(0 and 0) ->  14 Load(0 and 23) ->  11 Load(1 and 23) ->  35 Load(0 and 23) ->  38 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 203m
#
# Route for vehicle 8:
#  0 Load(0 and 0) ->  13 Load(0 and 15) ->  37 Load(0 and 0) ->  18 Load(0 and 10) ->  42 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 210m
#
# Route for vehicle 9:
#  0 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 0m
#
# Route for vehicle 10:
#  0 Load(0 and 0) ->  2 Load(1 and 0) ->  26 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 214m
#
# Route for vehicle 11:
#  0 Load(0 and 0) ->  5 Load(1 and 0) ->  19 Load(1 and 22) ->  29 Load(0 and 22) ->  43 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 185m
#
# Route for vehicle 12:
#  0 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 0m
#
# Route for vehicle 13:
#  0 Load(0 and 0) ->  7 Load(1 and 0) ->  24 Load(1 and 5) ->  31 Load(0 and 5) ->  48 Load(0 and 0) ->  21 Load(0 and 10) ->  45 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 176m
#
# Maximum of all routes: 214m
# Objective: 22544
# Route for vehicle 0:
#  0 Load(0 and 0) ->  18 Load(0 and 9) ->  8 Load(1 and 9) ->  48 Load(1 and 0) ->  38 Load(0 and 0) ->  14 Load(1 and 0) ->  24 Load(1 and 24) ->  54 Load(1 and 0) ->  44 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 203m
#
# Route for vehicle 1:
#  0 Load(0 and 0) ->  6 Load(1 and 0) ->  27 Load(1 and 11) ->  36 Load(0 and 11) ->  57 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 192m
#
# Route for vehicle 2:
#  0 Load(0 and 0) ->  21 Load(0 and 10) ->  4 Load(1 and 10) ->  23 Load(1 and 26) ->  34 Load(0 and 26) ->  51 Load(0 and 16) ->  53 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 190m
#
# Route for vehicle 3:
#  0 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 0m
#
# Route for vehicle 4:
#  0 Load(0 and 0) ->  17 Load(0 and 5) ->  3 Load(1 and 5) ->  33 Load(0 and 5) ->  47 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 197m
#
# Route for vehicle 5:
#  0 Load(0 and 0) ->  7 Load(1 and 0) ->  37 Load(0 and 0) ->  20 Load(0 and 5) ->  10 Load(1 and 5) ->  50 Load(1 and 0) ->  40 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 154m
#
# Route for vehicle 6:
#  0 Load(0 and 0) ->  5 Load(1 and 0) ->  35 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 140m
#
# Route for vehicle 7:
#  0 Load(0 and 0) ->  29 Load(0 and 16) ->  12 Load(1 and 16) ->  42 Load(0 and 16) ->  59 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 198m
#
# Route for vehicle 8:
#  0 Load(0 and 0) ->  25 Load(0 and 24) ->  55 Load(0 and 0) ->  26 Load(0 and 18) ->  56 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 203m
#
# Route for vehicle 9:
#  0 Load(0 and 0) ->  9 Load(1 and 0) ->  39 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 198m
#
# Route for vehicle 10:
#  0 Load(0 and 0) ->  28 Load(0 and 16) ->  19 Load(0 and 32) ->  2 Load(1 and 32) ->  58 Load(1 and 16) ->  32 Load(0 and 16) ->  49 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 185m
#
# Route for vehicle 11:
#  0 Load(0 and 0) ->  15 Load(0 and 20) ->  45 Load(0 and 0) ->  13 Load(1 and 0) ->  43 Load(0 and 0) ->  11 Load(1 and 0) ->  41 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 196m
#
# Route for vehicle 12:
#  0 Load(0 and 0) ->  1 Load(1 and 0) ->  30 Load(1 and 6) ->  16 Load(1 and 26) ->  22 Load(1 and 31) ->  46 Load(1 and 11) ->  52 Load(1 and 6) ->  31 Load(0 and 6) ->  60 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 188m
#
# Maximum of all routes: 203m
# Objective: 22747
# Route for vehicle 0:
#  0 Load(0 and 0) ->  24 Load(0 and 11) ->  10 Load(1 and 11) ->  59 Load(1 and 0) ->  31 Load(1 and 13) ->  66 Load(1 and 0) ->  45 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 204m
#
# Route for vehicle 1:
#  0 Load(0 and 0) ->  16 Load(1 and 0) ->  22 Load(1 and 18) ->  51 Load(0 and 18) ->  57 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 189m
#
# Route for vehicle 2:
#  0 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 0m
#
# Route for vehicle 3:
#  0 Load(0 and 0) ->  20 Load(0 and 17) ->  7 Load(1 and 17) ->  34 Load(1 and 30) ->  42 Load(0 and 30) ->  55 Load(0 and 13) ->  69 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 184m
#
# Route for vehicle 4:
#  0 Load(0 and 0) ->  28 Load(0 and 23) ->  12 Load(1 and 23) ->  63 Load(1 and 0) ->  18 Load(1 and 24) ->  30 Load(1 and 33) ->  47 Load(0 and 33) ->  53 Load(0 and 9) ->  65 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 202m
#
# Route for vehicle 5:
#  0 Load(0 and 0) ->  11 Load(1 and 0) ->  27 Load(1 and 17) ->  46 Load(0 and 17) ->  62 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 200m
#
# Route for vehicle 6:
#  0 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 0m
#
# Route for vehicle 7:
#  0 Load(0 and 0) ->  4 Load(1 and 0) ->  39 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 127m
#
# Route for vehicle 8:
#  0 Load(0 and 0) ->  5 Load(1 and 0) ->  26 Load(1 and 9) ->  40 Load(0 and 9) ->  61 Load(0 and 0) ->  3 Load(1 and 0) ->  25 Load(1 and 16) ->  38 Load(0 and 16) ->  60 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 203m
#
# Route for vehicle 9:
#  0 Load(0 and 0) ->  15 Load(1 and 0) ->  50 Load(0 and 0) ->  2 Load(1 and 0) ->  29 Load(1 and 24) ->  19 Load(1 and 29) ->  37 Load(0 and 29) ->  54 Load(0 and 24) ->  8 Load(1 and 24) ->  64 Load(1 and 0) ->  43 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 205m
#
# Route for vehicle 10:
#  0 Load(0 and 0) ->  35 Load(0 and 21) ->  33 Load(0 and 39) ->  70 Load(0 and 18) ->  1 Load(1 and 18) ->  68 Load(1 and 0) ->  36 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 195m
#
# Route for vehicle 11:
#  0 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 0m
#
# Route for vehicle 12:
#  0 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 0m
#
# Route for vehicle 13:
#  0 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 0m
#
# Route for vehicle 14:
#  0 Load(0 and 0) ->  14 Load(1 and 0) ->  21 Load(1 and 23) ->  56 Load(1 and 0) ->  32 Load(1 and 20) ->  49 Load(0 and 20) ->  67 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 173m
#
# Route for vehicle 15:
#  0 Load(0 and 0) ->  6 Load(1 and 0) ->  41 Load(0 and 0) ->  13 Load(1 and 0) ->  48 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 161m
#
# Route for vehicle 16:
#  0 Load(0 and 0) ->  9 Load(1 and 0) ->  23 Load(1 and 6) ->  17 Load(1 and 29) ->  52 Load(1 and 6) ->  58 Load(1 and 0) ->  44 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 204m
#
# Maximum of all routes: 205m
# Objective: 21707
# Route for vehicle 0:
#  0 Load(0 and 0) ->  12 Load(1 and 0) ->  46 Load(0 and 0) ->  5 Load(1 and 0) ->  39 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 164m
#
# Route for vehicle 1:
#  0 Load(0 and 0) ->  8 Load(1 and 0) ->  21 Load(1 and 21) ->  42 Load(0 and 21) ->  2 Load(1 and 21) ->  36 Load(0 and 21) ->  55 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 189m
#
# Route for vehicle 2:
#  0 Load(0 and 0) ->  32 Load(0 and 19) ->  7 Load(1 and 19) ->  66 Load(1 and 0) ->  41 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 181m
#
# Route for vehicle 3:
#  0 Load(0 and 0) ->  11 Load(1 and 0) ->  45 Load(0 and 0) ->  1 Load(1 and 0) ->  35 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 104m
#
# Route for vehicle 4:
#  0 Load(0 and 0) ->  9 Load(1 and 0) ->  22 Load(1 and 8) ->  56 Load(1 and 0) ->  43 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 191m
#
# Route for vehicle 5:
#  0 Load(0 and 0) ->  13 Load(1 and 0) ->  23 Load(1 and 12) ->  47 Load(0 and 12) ->  57 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 178m
#
# Route for vehicle 6:
#  0 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 0m
#
# Route for vehicle 7:
#  0 Load(0 and 0) ->  26 Load(0 and 6) ->  3 Load(1 and 6) ->  37 Load(0 and 6) ->  60 Load(0 and 0) ->  17 Load(1 and 0) ->  20 Load(1 and 22) ->  54 Load(1 and 0) ->  51 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 189m
#
# Route for vehicle 8:
#  0 Load(0 and 0) ->  24 Load(0 and 20) ->  15 Load(1 and 20) ->  58 Load(1 and 0) ->  49 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 187m
#
# Route for vehicle 9:
#  0 Load(0 and 0) ->  33 Load(0 and 19) ->  27 Load(0 and 38) ->  67 Load(0 and 19) ->  4 Load(1 and 19) ->  61 Load(1 and 0) ->  38 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 178m
#
# Route for vehicle 10:
#  0 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 0m
#
# Route for vehicle 11:
#  0 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 0m
#
# Route for vehicle 12:
#  0 Load(0 and 0) ->  28 Load(0 and 16) ->  16 Load(1 and 16) ->  62 Load(1 and 0) ->  50 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 192m
#
# Route for vehicle 13:
#  0 Load(0 and 0) ->  30 Load(0 and 19) ->  29 Load(0 and 27) ->  63 Load(0 and 19) ->  18 Load(1 and 19) ->  64 Load(1 and 0) ->  52 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 184m
#
# Route for vehicle 14:
#  0 Load(0 and 0) ->  19 Load(0 and 10) ->  25 Load(0 and 32) ->  59 Load(0 and 10) ->  53 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 191m
#
# Route for vehicle 15:
#  0 Load(0 and 0) ->  31 Load(0 and 10) ->  34 Load(0 and 27) ->  65 Load(0 and 17) ->  6 Load(1 and 17) ->  40 Load(0 and 17) ->  14 Load(1 and 17) ->  68 Load(1 and 0) ->  48 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 191m
#
# Route for vehicle 16:
#  0 Load(0 and 0) ->  10 Load(1 and 0) ->  44 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 188m
#
# Route for vehicle 17:
#  0 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 0m
#
# Route for vehicle 18:
#  0 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 0m
#
# Maximum of all routes: 192m
# Objective: 24295
# Route for vehicle 0:
#  0 Load(0 and 0) ->  34 Load(0 and 10) ->  24 Load(0 and 32) ->  4 Load(1 and 32) ->  64 Load(1 and 10) ->  44 Load(0 and 10) ->  74 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 214m
#
# Route for vehicle 1:
#  0 Load(0 and 0) ->  18 Load(1 and 0) ->  58 Load(0 and 0) ->  20 Load(1 and 0) ->  35 Load(1 and 13) ->  60 Load(0 and 13) ->  75 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 180m
#
# Route for vehicle 2:
#  0 Load(0 and 0) ->  27 Load(0 and 7) ->  23 Load(0 and 30) ->  63 Load(0 and 7) ->  6 Load(1 and 7) ->  67 Load(1 and 0) ->  46 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 212m
#
# Route for vehicle 3:
#  0 Load(0 and 0) ->  17 Load(1 and 0) ->  39 Load(1 and 21) ->  57 Load(0 and 21) ->  29 Load(0 and 31) ->  3 Load(1 and 31) ->  69 Load(1 and 21) ->  79 Load(1 and 0) ->  43 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 206m
#
# Route for vehicle 4:
#  0 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 0m
#
# Route for vehicle 5:
#  0 Load(0 and 0) ->  19 Load(1 and 0) ->  59 Load(0 and 0) ->  2 Load(1 and 0) ->  30 Load(1 and 18) ->  42 Load(0 and 18) ->  70 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 216m
#
# Route for vehicle 6:
#  0 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 0m
#
# Route for vehicle 7:
#  0 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 0m
#
# Route for vehicle 8:
#  0 Load(0 and 0) ->  38 Load(0 and 14) ->  28 Load(0 and 25) ->  14 Load(1 and 25) ->  78 Load(1 and 11) ->  54 Load(0 and 11) ->  68 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 212m
#
# Route for vehicle 9:
#  0 Load(0 and 0) ->  31 Load(0 and 14) ->  13 Load(1 and 14) ->  71 Load(1 and 0) ->  21 Load(1 and 18) ->  53 Load(0 and 18) ->  61 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 211m
#
# Route for vehicle 10:
#  0 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 0m
#
# Route for vehicle 11:
#  0 Load(0 and 0) ->  7 Load(1 and 0) ->  47 Load(0 and 0) ->  5 Load(1 and 0) ->  32 Load(1 and 16) ->  45 Load(0 and 16) ->  72 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 215m
#
# Route for vehicle 12:
#  0 Load(0 and 0) ->  11 Load(1 and 0) ->  40 Load(1 and 13) ->  51 Load(0 and 13) ->  1 Load(1 and 13) ->  41 Load(0 and 13) ->  26 Load(0 and 25) ->  36 Load(0 and 32) ->  80 Load(0 and 19) ->  66 Load(0 and 7) ->  76 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 214m
#
# Route for vehicle 13:
#  0 Load(0 and 0) ->  10 Load(1 and 0) ->  50 Load(0 and 0) ->  15 Load(1 and 0) ->  55 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 214m
#
# Route for vehicle 14:
#  0 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 0m
#
# Route for vehicle 15:
#  0 Load(0 and 0) ->  8 Load(1 and 0) ->  37 Load(1 and 6) ->  48 Load(0 and 6) ->  77 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 216m
#
# Route for vehicle 16:
#  0 Load(0 and 0) ->  9 Load(1 and 0) ->  33 Load(1 and 16) ->  49 Load(0 and 16) ->  73 Load(0 and 0) ->  25 Load(0 and 20) ->  65 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 214m
#
# Route for vehicle 17:
#  0 Load(0 and 0) ->  16 Load(1 and 0) ->  22 Load(1 and 12) ->  62 Load(1 and 0) ->  56 Load(0 and 0) ->  12 Load(1 and 0) ->  52 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 171m
#
# Route for vehicle 18:
#  0 Load(0 and 0) ->  0 Load(0 and 0)
# Distance of the route: 0m
#
# Maximum of all routes: 216m

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
